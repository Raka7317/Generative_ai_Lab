# %% [markdown]
# <a href="https://colab.research.google.com/github/Raka7317/Generative_ai_Lab/blob/main/OR_GATE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# FEED FORWARD NEURAL NETWORK LAB(3)

# %%
import numpy as np

# %%
import pandas as pd

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
np.random.seed(0)

# %%
tf.random.set_seed(0)

# %%
X=np.array([[0,0],[0,1],[1,0],[1,1] ],dtype=np.float32)

# %%
Y=np.array([0,1,1,1],dtype=np.float32)

# %%
model=Sequential([
    Dense(8,activation='relu',input_shape=(2,)),
    Dense(1,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X,Y,epochs=1000,verbose=0)

# %%
print("probabilities:\n", model.predict(X))
print("Rounded output:\n", model.predict(X).round())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# probabilities:
#  [[0.380161  ]
#  [0.93255186]
#  [0.97837037]
#  [0.9985545 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Rounded output:
#  [[0.]
#  [1.]
#  [1.]
#  [1.]]

# %%
loss, acc=model.evaluate(X,Y,verbose=0)
print("Loss:",loss)
print("Accuracy:",acc)
# Out:
# Loss: 0.14285984635353088
# Accuracy: 1.0
